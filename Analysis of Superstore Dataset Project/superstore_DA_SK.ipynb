# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #load the dataset

# %%
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.drop(columns="Postal Code", inplace=True)
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
print(df["Ship Mode"].unique())
print(df["Segment"].unique())
print(df["Country"].unique())
print(df["Category"].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
# ['Furniture' 'Office Supplies' 'Technology']

# %%
print(df["Ship Mode"].unique())
print(df["Segment"].unique())
print(df["Country"].unique())
print(df["Category"].unique())
print(df["Sub-Category"].unique())
print(df["Region"].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
# ['Furniture' 'Office Supplies' 'Technology']
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
# ['South' 'West' 'Central' 'East']

# %% [markdown]
# # Statistical description of the data

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Sales analysis based on region

# %%
df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# # Profit analysis based on region

# %%
df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("Segment")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Segment")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("State")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
df.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State Region  \
# 9989    Second Class  Consumer  United States        Miami     Florida  South
# 9990  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9991  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9992  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9993    Second Class  Consumer  United States  Westminster  California   West
#
#              Category Sub-Category    Sales  Quantity  Discount   Profit
# 9989        Furniture  Furnishings   25.248         3       0.2   4.1028
# 9990        Furniture  Furnishings   91.960         2       0.0  15.6332
# 9991       Technology       Phones  258.576         2       0.2  19.3932
# 9992  Office Supplies        Paper   29.600         4       0.0  13.3200
# 9993  Office Supplies   Appliances  243.160         2       0.0  72.9480

# %% [markdown]
# Top Selling Products in Superstore

# %%
category_group = df.groupby(["Category"]).sum()["Sales"]
category_group.head()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
top_selling_categories = category_group.sort_values(ascending=False)
top_3_selling_categories = pd.DataFrame(top_selling_categories.head())
top_3_selling_categories
# Out:
#                        Sales
# Category
# Technology       836154.0330
# Furniture        741999.7953
# Office Supplies  719047.0320

# %% [markdown]
# Plotting Top 3 Products in Superstore

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\arkay\appdata\roaming\python\python311\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\arkay\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
top_3_selling_categories.plot(kind = "bar")

plt.title("Top 3 Selling Categories in Superstore")

plt.xlabel("Category")
plt.ylabel("Total Profit")

plt.show()

# %% [markdown]
# Top Profitable Categories

# %%
category_group = df.groupby(["Category"]).sum()["Profit"]

top_profit_categories = category_group.sort_values(ascending=False)

top_3_profit_categories =pd.DataFrame(top_profit_categories[:3])
top_3_profit_categories
# Out:
#                       Profit
# Category
# Technology       145454.9481
# Office Supplies  122490.8008
# Furniture         18451.2728

# %%
top_3_profit_categories.plot(kind="bar")

plt.title("Top 3 Profit Categories in Superstore")

plt.xlabel("Category")
plt.ylabel("Total Profit")

plt.show()

# %%
top_3_profit_categories.index == top_3_selling_categories.index
# Out:
# array([ True, False, False])

# %%
list(top_3_profit_categories.index)
# Out:
# ['Technology', 'Office Supplies', 'Furniture']

# %%
list(top_3_selling_categories.index)
# Out:
# ['Technology', 'Furniture', 'Office Supplies']

# %%
df.Region.value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %% [markdown]
# Which Region and place generates the most sales?

# %%
df_places = df[['Country','City','State','Region']]
df_places.head()
# Out:
#          Country             City       State Region
# 0  United States        Henderson    Kentucky  South
# 1  United States        Henderson    Kentucky  South
# 2  United States      Los Angeles  California   West
# 3  United States  Fort Lauderdale     Florida  South
# 4  United States  Fort Lauderdale     Florida  South

# %%
for place in df_places.columns:
    print(place,':',df_places[place].nunique())
# Out:
# Country : 1
# City : 531
# State : 49
# Region : 4

# %%
df_places = df[['City','State','Region','Sales','Profit']]
df_places.head()
# Out:
#               City       State Region     Sales    Profit
# 0        Henderson    Kentucky  South  261.9600   41.9136
# 1        Henderson    Kentucky  South  731.9400  219.5820
# 2      Los Angeles  California   West   14.6200    6.8714
# 3  Fort Lauderdale     Florida  South  957.5775 -383.0310
# 4  Fort Lauderdale     Florida  South   22.3680    2.5164

# %%
# Group the data by Region and City and calculate the total sales for each group
region_sales = df_places.groupby(['Region'], as_index=False).sum()
region_sales.sort_values(by='Sales', ascending=False, inplace=True)

# Plot the total sales geProfitnerated by each region and city
plt.figure(figsize=(10,5))
plt.bar(region_sales['Region'], region_sales['Sales'], align='center',)
plt.xlabel("Region")
plt.ylabel("Sales")
plt.title("Sales Generated by Region")
plt.xticks(rotation=90)
plt.show()
region_sales
# Out:
#     Region                                               City  \
# 3     West  Los AngelesLos AngelesLos AngelesLos AngelesLo...
# 1     East  PhiladelphiaPhiladelphiaPhiladelphiaPhiladelph...
# 0  Central  Fort WorthFort WorthMadisonFremontFremontHoust...
# 2    South  HendersonHendersonFort LauderdaleFort Lauderda...
#
#                                                State        Sales       Profit
# 3  CaliforniaCaliforniaCaliforniaCaliforniaCalifo...  725457.8245  108418.4489
# 1  PennsylvaniaPennsylvaniaPennsylvaniaPennsylvan...  678781.2400   91522.7800
# 0  TexasTexasWisconsinNebraskaNebraskaTexasTexasT...  501239.8908   39706.3625
# 2  KentuckyKentuckyFloridaFloridaNorth CarolinaFl...  391721.9050   46749.4303

# %%
# Group the data by Region and City and calculate the total sales for each group
region_profit = df_places.groupby(['Region'], as_index=False).sum()
region_profit.sort_values(by='Profit', ascending=False, inplace=True)

# Plot the total sales generated by each region and city
plt.figure(figsize=(10,5))
plt.bar(region_profit['Region'], region_profit['Profit'], align='center',)
plt.xlabel("Region")
plt.ylabel("Profit")
plt.title("Profit Generated by Region")
plt.xticks(rotation=90)
plt.show()
region_profit
# Out:
#     Region                                               City  \
# 3     West  Los AngelesLos AngelesLos AngelesLos AngelesLo...
# 1     East  PhiladelphiaPhiladelphiaPhiladelphiaPhiladelph...
# 2    South  HendersonHendersonFort LauderdaleFort Lauderda...
# 0  Central  Fort WorthFort WorthMadisonFremontFremontHoust...
#
#                                                State        Sales       Profit
# 3  CaliforniaCaliforniaCaliforniaCaliforniaCalifo...  725457.8245  108418.4489
# 1  PennsylvaniaPennsylvaniaPennsylvaniaPennsylvan...  678781.2400   91522.7800
# 2  KentuckyKentuckyFloridaFloridaNorth CarolinaFl...  391721.9050   46749.4303
# 0  TexasTexasWisconsinNebraskaNebraskaTexasTexasT...  501239.8908   39706.3625

# %%
state_sales = df_places.groupby(['State'], as_index=False).sum()
state_sales.sort_values(by='Sales', ascending=False, inplace=True)


plt.figure(figsize=(22,10))
plt.bar(state_sales['State'], state_sales['Sales'], align='center',)
plt.xlabel("State")
plt.ylabel("Sales")
plt.title("Sales Generated by State")
plt.xticks(rotation=90)

plt.show()
state_sales
# Out:
#                    State                                               City  \
# 3             California  Los AngelesLos AngelesLos AngelesLos AngelesLo...
# 30              New York  New York CityNew York CityTroyTroyTroyTroyTroy...
# 41                 Texas  Fort WorthFort WorthHoustonRichardsonRichardso...
# 45            Washington  SeattleSeattleSeattleSeattleSeattleDes MoinesD...
# 36          Pennsylvania  PhiladelphiaPhiladelphiaPhiladelphiaPhiladelph...
# 8                Florida  Fort LauderdaleFort LauderdaleMelbourneTampaTa...
# 11              Illinois  NapervilleChicagoChicagoChicagoChicagoChicagoO...
# 33                  Ohio  ColumbusColumbusColumbusColumbusColumbusColumb...
# 20              Michigan  WestlandJacksonSaginawSaginawSaginawSaginawSag...
# 44              Virginia  SpringfieldArlingtonWaynesboroWaynesboroWaynes...
# 31        North Carolina  ConcordDurhamCharlotteCharlotteCharlotteCharlo...
# 12               Indiana  New AlbanyNew AlbanyNew AlbanyNew AlbanyColumb...
# 9                Georgia  ColumbusColumbusAtlantaAtlantaAtlantaAtlantaWa...
# 15              Kentucky  HendersonHendersonRichmondHendersonHendersonRi...
# 28            New Jersey  WestfieldMorristownBellevilleBellevilleBellevi...
# 1                Arizona  GilbertGilbertPhoenixPhoenixScottsdaleScottsda...
# 47             Wisconsin  MadisonFranklinFranklinFranklinFranklinGreen B...
# 4               Colorado  AuroraAuroraAuroraDenverDenverColorado Springs...
# 40             Tennessee  MemphisMemphisMemphisBristolFranklinColumbiaCo...
# 21             Minnesota  EaganEaganRochesterRochesterMinneapolisMinneap...
# 19         Massachusetts  LowellLowellLowellFranklinLawrenceLawrenceLowe...
# 6               Delaware  DoverDoverWilmingtonWilmingtonWilmingtonWilmin...
# 18              Maryland  ColumbiaClintonClintonRockvilleRockvilleClinto...
# 37          Rhode Island  WarwickWarwickProvidenceProvidenceProvidencePr...
# 23              Missouri  IndependenceGladstoneGladstoneJefferson CitySa...
# 34              Oklahoma  EdmondEdmondNormanTulsaMuskogeeMuskogeeTulsaOk...
# 0                Alabama  DecaturDecaturMontgomeryMontgomeryFlorenceFlor...
# 35                Oregon  PortlandPortlandPortlandPortlandSalemSalemSale...
# 26                Nevada  Las VegasRenoRenoNorth Las VegasNorth Las Vega...
# 5            Connecticut  FairfieldManchesterManchesterManchesterManches...
# 2               Arkansas  FayettevilleFayettevilleJonesboroJonesboroJone...
# 42                  Utah  West JordanOremLaytonOremOremProvoPleasant Gro...
# 22           Mississippi  JacksonJacksonJacksonJacksonJacksonJacksonGulf...
# 16             Louisiana  MonroeMonroeMonroeBossier CityBossier CityBoss...
# 43               Vermont  BurlingtonBurlingtonBurlingtonBurlingtonBurlin...
# 38        South Carolina  ColumbiaColumbiaColumbiaFlorenceFlorenceFloren...
# 25              Nebraska  FremontFremontOmahaOmahaOmahaOmahaOmahaOmahaFr...
# 27         New Hampshire  ConcordConcordConcordConcordConcordDoverDoverD...
# 24               Montana  Great FallsGreat FallsGreat FallsGreat FallsMi...
# 29            New Mexico  CarlsbadFarmingtonFarmingtonAlbuquerqueAlbuque...
# 13                  Iowa  UrbandaleUrbandaleDes MoinesDes MoinesDes Moin...
# 10                 Idaho  MeridianMeridianMeridianBoiseBoiseBoiseLewisto...
# 14                Kansas  OlatheOverland ParkOverland ParkOverland ParkO...
# 7   District of Columbia  WashingtonWashingtonWashingtonWashingtonWashin...
# 48               Wyoming                                           Cheyenne
# 39          South Dakota  Sioux FallsSioux FallsSioux FallsSioux FallsSi...
# 17                 Maine  BangorBangorLewistonLewistonLewistonBangorBang...
# 46         West Virginia                   WheelingWheelingWheelingWheeling
# 32          North Dakota                FargoFargoFargoFargoFargoFargoFargo
#
#                                                Region        Sales      Profit
# 3   WestWestWestWestWestWestWestWestWestWestWestWe...  457687.6315  76381.3871
# 30  EastEastEastEastEastEastEastEastEastEastEastEa...  310876.2710  74038.5486
# 41  CentralCentralCentralCentralCentralCentralCent...  170188.0458 -25729.3563
# 45  WestWestWestWestWestWestWestWestWestWestWestWe...  138641.2700  33402.6517
# 36  EastEastEastEastEastEastEastEastEastEastEastEa...  116511.9140 -15559.9603
# 8   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   89473.7080  -3399.3017
# 11  CentralCentralCentralCentralCentralCentralCent...   80166.1010 -12607.8870
# 33  EastEastEastEastEastEastEastEastEastEastEastEa...   78258.1360 -16971.3766
# 20  CentralCentralCentralCentralCentralCentralCent...   76269.6140  24463.1876
# 44  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   70636.7200  18597.9504
# 31  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   55603.1640  -7490.9122
# 12  CentralCentralCentralCentralCentralCentralCent...   53555.3600  18382.9363
# 9   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   49095.8400  16250.0433
# 15  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   36591.7500  11199.6966
# 28  EastEastEastEastEastEastEastEastEastEastEastEa...   35764.3120   9772.9138
# 1   WestWestWestWestWestWestWestWestWestWestWestWe...   35282.0010  -3427.9246
# 47  CentralCentralCentralCentralCentralCentralCent...   32114.6100   8401.8004
# 4   WestWestWestWestWestWestWestWestWestWestWestWe...   32108.1180  -6527.8579
# 40  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   30661.8730  -5341.6936
# 21  CentralCentralCentralCentralCentralCentralCent...   29863.1500  10823.1874
# 19  EastEastEastEastEastEastEastEastEastEastEastEa...   28634.4340   6785.5016
# 6   EastEastEastEastEastEastEastEastEastEastEastEa...   27451.0690   9977.3748
# 18  EastEastEastEastEastEastEastEastEastEastEastEa...   23705.5230   7031.1788
# 37  EastEastEastEastEastEastEastEastEastEastEastEa...   22627.9560   7285.6293
# 23  CentralCentralCentralCentralCentralCentralCent...   22205.1500   6436.2105
# 34  CentralCentralCentralCentralCentralCentralCent...   19683.3900   4853.9560
# 0   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   19510.6400   5786.8253
# 35  WestWestWestWestWestWestWestWestWestWestWestWe...   17431.1500  -1190.4705
# 26  WestWestWestWestWestWestWestWestWestWestWestWe...   16729.1020   3316.7659
# 5   EastEastEastEastEastEastEastEastEastEastEastEa...   13384.3570   3511.4918
# 2   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   11678.1300   4008.6871
# 42  WestWestWestWestWestWestWestWestWestWestWestWe...   11220.0560   2546.5335
# 22  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   10771.3400   3172.9762
# 16  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...    9217.0300   2196.1023
# 43       EastEastEastEastEastEastEastEastEastEastEast    8929.3700   2244.9783
# 38  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...    8481.7100   1769.0566
# 25  CentralCentralCentralCentralCentralCentralCent...    7464.9300   2037.0942
# 27  EastEastEastEastEastEastEastEastEastEastEastEa...    7292.5240   1706.5028
# 24  WestWestWestWestWestWestWestWestWestWestWestWe...    5589.3520   1833.3285
# 29  WestWestWestWestWestWestWestWestWestWestWestWe...    4783.5220   1157.1161
# 13  CentralCentralCentralCentralCentralCentralCent...    4579.7600   1183.8119
# 10  WestWestWestWestWestWestWestWestWestWestWestWe...    4382.4860    826.7231
# 14  CentralCentralCentralCentralCentralCentralCent...    2914.3100    836.4435
# 7            EastEastEastEastEastEastEastEastEastEast    2865.0200   1059.5893
# 48                                               West    1603.1360    100.1960
# 39  CentralCentralCentralCentralCentralCentralCent...    1315.5600    394.8283
# 17                   EastEastEastEastEastEastEastEast    1270.5300    454.4862
# 46                                   EastEastEastEast    1209.8240    185.9216
# 32  CentralCentralCentralCentralCentralCentralCentral     919.9100    230.1497

# %%
state_profit = df_places.groupby(['State'], as_index=False).sum()
state_profit.sort_values(by='Profit', ascending=False, inplace=True)


plt.figure(figsize=(22,10))
plt.bar(state_profit['State'], state_profit['Profit'], align='center',)
plt.xlabel("State")
plt.ylabel("Profit")
plt.title("Sales Generated by State")
plt.xticks(rotation=90)

plt.show()
state_profit
# Out:
#                    State                                               City  \
# 3             California  Los AngelesLos AngelesLos AngelesLos AngelesLo...
# 30              New York  New York CityNew York CityTroyTroyTroyTroyTroy...
# 45            Washington  SeattleSeattleSeattleSeattleSeattleDes MoinesD...
# 20              Michigan  WestlandJacksonSaginawSaginawSaginawSaginawSag...
# 44              Virginia  SpringfieldArlingtonWaynesboroWaynesboroWaynes...
# 12               Indiana  New AlbanyNew AlbanyNew AlbanyNew AlbanyColumb...
# 9                Georgia  ColumbusColumbusAtlantaAtlantaAtlantaAtlantaWa...
# 15              Kentucky  HendersonHendersonRichmondHendersonHendersonRi...
# 21             Minnesota  EaganEaganRochesterRochesterMinneapolisMinneap...
# 6               Delaware  DoverDoverWilmingtonWilmingtonWilmingtonWilmin...
# 28            New Jersey  WestfieldMorristownBellevilleBellevilleBellevi...
# 47             Wisconsin  MadisonFranklinFranklinFranklinFranklinGreen B...
# 37          Rhode Island  WarwickWarwickProvidenceProvidenceProvidencePr...
# 18              Maryland  ColumbiaClintonClintonRockvilleRockvilleClinto...
# 19         Massachusetts  LowellLowellLowellFranklinLawrenceLawrenceLowe...
# 23              Missouri  IndependenceGladstoneGladstoneJefferson CitySa...
# 0                Alabama  DecaturDecaturMontgomeryMontgomeryFlorenceFlor...
# 34              Oklahoma  EdmondEdmondNormanTulsaMuskogeeMuskogeeTulsaOk...
# 2               Arkansas  FayettevilleFayettevilleJonesboroJonesboroJone...
# 5            Connecticut  FairfieldManchesterManchesterManchesterManches...
# 26                Nevada  Las VegasRenoRenoNorth Las VegasNorth Las Vega...
# 22           Mississippi  JacksonJacksonJacksonJacksonJacksonJacksonGulf...
# 42                  Utah  West JordanOremLaytonOremOremProvoPleasant Gro...
# 43               Vermont  BurlingtonBurlingtonBurlingtonBurlingtonBurlin...
# 16             Louisiana  MonroeMonroeMonroeBossier CityBossier CityBoss...
# 25              Nebraska  FremontFremontOmahaOmahaOmahaOmahaOmahaOmahaFr...
# 24               Montana  Great FallsGreat FallsGreat FallsGreat FallsMi...
# 38        South Carolina  ColumbiaColumbiaColumbiaFlorenceFlorenceFloren...
# 27         New Hampshire  ConcordConcordConcordConcordConcordDoverDoverD...
# 13                  Iowa  UrbandaleUrbandaleDes MoinesDes MoinesDes Moin...
# 29            New Mexico  CarlsbadFarmingtonFarmingtonAlbuquerqueAlbuque...
# 7   District of Columbia  WashingtonWashingtonWashingtonWashingtonWashin...
# 14                Kansas  OlatheOverland ParkOverland ParkOverland ParkO...
# 10                 Idaho  MeridianMeridianMeridianBoiseBoiseBoiseLewisto...
# 17                 Maine  BangorBangorLewistonLewistonLewistonBangorBang...
# 39          South Dakota  Sioux FallsSioux FallsSioux FallsSioux FallsSi...
# 32          North Dakota                FargoFargoFargoFargoFargoFargoFargo
# 46         West Virginia                   WheelingWheelingWheelingWheeling
# 48               Wyoming                                           Cheyenne
# 35                Oregon  PortlandPortlandPortlandPortlandSalemSalemSale...
# 8                Florida  Fort LauderdaleFort LauderdaleMelbourneTampaTa...
# 1                Arizona  GilbertGilbertPhoenixPhoenixScottsdaleScottsda...
# 40             Tennessee  MemphisMemphisMemphisBristolFranklinColumbiaCo...
# 4               Colorado  AuroraAuroraAuroraDenverDenverColorado Springs...
# 31        North Carolina  ConcordDurhamCharlotteCharlotteCharlotteCharlo...
# 11              Illinois  NapervilleChicagoChicagoChicagoChicagoChicagoO...
# 36          Pennsylvania  PhiladelphiaPhiladelphiaPhiladelphiaPhiladelph...
# 33                  Ohio  ColumbusColumbusColumbusColumbusColumbusColumb...
# 41                 Texas  Fort WorthFort WorthHoustonRichardsonRichardso...
#
#                                                Region        Sales      Profit
# 3   WestWestWestWestWestWestWestWestWestWestWestWe...  457687.6315  76381.3871
# 30  EastEastEastEastEastEastEastEastEastEastEastEa...  310876.2710  74038.5486
# 45  WestWestWestWestWestWestWestWestWestWestWestWe...  138641.2700  33402.6517
# 20  CentralCentralCentralCentralCentralCentralCent...   76269.6140  24463.1876
# 44  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   70636.7200  18597.9504
# 12  CentralCentralCentralCentralCentralCentralCent...   53555.3600  18382.9363
# 9   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   49095.8400  16250.0433
# 15  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   36591.7500  11199.6966
# 21  CentralCentralCentralCentralCentralCentralCent...   29863.1500  10823.1874
# 6   EastEastEastEastEastEastEastEastEastEastEastEa...   27451.0690   9977.3748
# 28  EastEastEastEastEastEastEastEastEastEastEastEa...   35764.3120   9772.9138
# 47  CentralCentralCentralCentralCentralCentralCent...   32114.6100   8401.8004
# 37  EastEastEastEastEastEastEastEastEastEastEastEa...   22627.9560   7285.6293
# 18  EastEastEastEastEastEastEastEastEastEastEastEa...   23705.5230   7031.1788
# 19  EastEastEastEastEastEastEastEastEastEastEastEa...   28634.4340   6785.5016
# 23  CentralCentralCentralCentralCentralCentralCent...   22205.1500   6436.2105
# 0   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   19510.6400   5786.8253
# 34  CentralCentralCentralCentralCentralCentralCent...   19683.3900   4853.9560
# 2   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   11678.1300   4008.6871
# 5   EastEastEastEastEastEastEastEastEastEastEastEa...   13384.3570   3511.4918
# 26  WestWestWestWestWestWestWestWestWestWestWestWe...   16729.1020   3316.7659
# 22  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   10771.3400   3172.9762
# 42  WestWestWestWestWestWestWestWestWestWestWestWe...   11220.0560   2546.5335
# 43       EastEastEastEastEastEastEastEastEastEastEast    8929.3700   2244.9783
# 16  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...    9217.0300   2196.1023
# 25  CentralCentralCentralCentralCentralCentralCent...    7464.9300   2037.0942
# 24  WestWestWestWestWestWestWestWestWestWestWestWe...    5589.3520   1833.3285
# 38  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...    8481.7100   1769.0566
# 27  EastEastEastEastEastEastEastEastEastEastEastEa...    7292.5240   1706.5028
# 13  CentralCentralCentralCentralCentralCentralCent...    4579.7600   1183.8119
# 29  WestWestWestWestWestWestWestWestWestWestWestWe...    4783.5220   1157.1161
# 7            EastEastEastEastEastEastEastEastEastEast    2865.0200   1059.5893
# 14  CentralCentralCentralCentralCentralCentralCent...    2914.3100    836.4435
# 10  WestWestWestWestWestWestWestWestWestWestWestWe...    4382.4860    826.7231
# 17                   EastEastEastEastEastEastEastEast    1270.5300    454.4862
# 39  CentralCentralCentralCentralCentralCentralCent...    1315.5600    394.8283
# 32  CentralCentralCentralCentralCentralCentralCentral     919.9100    230.1497
# 46                                   EastEastEastEast    1209.8240    185.9216
# 48                                               West    1603.1360    100.1960
# 35  WestWestWestWestWestWestWestWestWestWestWestWe...   17431.1500  -1190.4705
# 8   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   89473.7080  -3399.3017
# 1   WestWestWestWestWestWestWestWestWestWestWestWe...   35282.0010  -3427.9246
# 40  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   30661.8730  -5341.6936
# 4   WestWestWestWestWestWestWestWestWestWestWestWe...   32108.1180  -6527.8579
# 31  SouthSouthSouthSouthSouthSouthSouthSouthSouthS...   55603.1640  -7490.9122
# 11  CentralCentralCentralCentralCentralCentralCent...   80166.1010 -12607.8870
# 36  EastEastEastEastEastEastEastEastEastEastEastEa...  116511.9140 -15559.9603
# 33  EastEastEastEastEastEastEastEastEastEastEastEa...   78258.1360 -16971.3766
# 41  CentralCentralCentralCentralCentralCentralCent...  170188.0458 -25729.3563

# %%
city_sales = df_places.groupby('City', as_index=False).sum()

# Sort the data by Sales in descending order
city_sales.sort_values(by='Sales', ascending=False, inplace=True)

# Select the top 5 cities
top_5_cities_sales = city_sales.head()

plt.bar(top_5_cities_sales['City'], top_5_cities_sales['Sales'], align='center')
plt.xlabel("City")
plt.ylabel("Sales")
plt.title("Top 5 Cities by Sales")
plt.xticks(rotation=90)
plt.show()
top_5_cities_sales
# Out:
#               City                                              State  \
# 329  New York City  New YorkNew YorkNew YorkNew YorkNew YorkNew Yo...
# 266    Los Angeles  CaliforniaCaliforniaCaliforniaCaliforniaCalifo...
# 452        Seattle  WashingtonWashingtonWashingtonWashingtonWashin...
# 438  San Francisco  CaliforniaCaliforniaCaliforniaCaliforniaCalifo...
# 374   Philadelphia  PennsylvaniaPennsylvaniaPennsylvaniaPennsylvan...
#
#                                                 Region       Sales      Profit
# 329  EastEastEastEastEastEastEastEastEastEastEastEa...  256368.161  62036.9837
# 266  WestWestWestWestWestWestWestWestWestWestWestWe...  175851.341  30440.7579
# 452  WestWestWestWestWestWestWestWestWestWestWestWe...  119540.742  29156.0967
# 438  WestWestWestWestWestWestWestWestWestWestWestWe...  112669.092  17507.3854
# 374  EastEastEastEastEastEastEastEastEastEastEastEa...  109077.013 -13837.7674

# %%
city_profit = df_places.groupby('City', as_index=False).sum()

# Sort the data by Sales in descending order
city_profit.sort_values(by='Profit', ascending=False, inplace=True)

# Select the top 5 cities
top_5_cities_profit =city_profit.head()

plt.bar(top_5_cities_profit['City'], top_5_cities_profit['Profit'], align='center')
plt.xlabel("City")
plt.ylabel("Profit")
plt.title("Top 5 Cities by Profit")
plt.xticks(rotation=90)

plt.show()
top_5_cities_profit
# Out:
#               City                                              State  \
# 329  New York City  New YorkNew YorkNew YorkNew YorkNew YorkNew Yo...
# 266    Los Angeles  CaliforniaCaliforniaCaliforniaCaliforniaCalifo...
# 452        Seattle  WashingtonWashingtonWashingtonWashingtonWashin...
# 438  San Francisco  CaliforniaCaliforniaCaliforniaCaliforniaCalifo...
# 123        Detroit  MichiganMichiganMichiganMichiganMichiganMichig...
#
#                                                 Region       Sales      Profit
# 329  EastEastEastEastEastEastEastEastEastEastEastEa...  256368.161  62036.9837
# 266  WestWestWestWestWestWestWestWestWestWestWestWe...  175851.341  30440.7579
# 452  WestWestWestWestWestWestWestWestWestWestWestWe...  119540.742  29156.0967
# 438  WestWestWestWestWestWestWestWestWestWestWestWe...  112669.092  17507.3854
# 123  CentralCentralCentralCentralCentralCentralCent...   42446.944  13181.7908

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
df.Discount.value_counts()
# Out:
# Discount
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: count, dtype: int64

# %%
# Create a scatter plot between sales and discounts
plt.scatter(df['Sales'],df['Discount'])

plt.ylabel("Discount")
plt.xlabel("Sales")
plt.show()

# %%
# Group the data by the discount and compute the average sales
discount_group = df.groupby(["Discount"]).sum()[["Profit"]]

ax = discount_group.plot(kind="bar")

ax.set_ylabel("Profit")

plt.show()

# %%
# Group the data by product category and calculate the average profit for each category
avg_profit_margin_by_category = df.groupby('Category')['Profit'].sum()

print(avg_profit_margin_by_category)
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
df['Profit Margin'] = df['Profit'] / df['Sales']

# Group the data by product category and calculate the average profit margin for each category
avg_profit_margin_by_category = df.groupby('Category')['Profit Margin'].mean()

# Plot the average profit margin for each category as a bar chart
avg_profit_margin_by_category.plot(kind='bar')

# Add a title and labels to the chart
plt.title("Average Profit Margin by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Average Profit Margin")

plt.show()

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount  \
# 0  South        Furniture    Bookcases  261.9600         2      0.00
# 1  South        Furniture       Chairs  731.9400         3      0.00
# 2   West  Office Supplies       Labels   14.6200         2      0.00
# 3  South        Furniture       Tables  957.5775         5      0.45
# 4  South  Office Supplies      Storage   22.3680         2      0.20
#
#      Profit  Profit Margin
# 0   41.9136         0.1600
# 1  219.5820         0.3000
# 2    6.8714         0.4700
# 3 -383.0310        -0.4000
# 4    2.5164         0.1125

# %%
df.Segment.value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
pivot_table = df.pivot_table(index='Segment', columns='Ship Mode', values='Sales', aggfunc='sum')

# %%
pivot_table
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer     159168.9650  60596.359   231498.9496     710137.0714
# Corporate    105858.4699  45121.323   146126.0388     409040.5351
# Home Office   86400.9880  22645.443    81568.5810     239038.1365

# %%
# Plot the pivot table as a bar chart
pivot_table.plot(kind='bar', stacked=False)
plt.show()

# %%
#profit
pivot_table = df.pivot_table(index='Segment', columns='Ship Mode', values='Profit', aggfunc='sum')

pivot_table.plot(kind='bar', stacked=False)

# Show the plot
plt.show()

# %% [markdown]
# Data Visualization and Share Results

# %% [markdown]
# ![image.png](attachment:image.png)
